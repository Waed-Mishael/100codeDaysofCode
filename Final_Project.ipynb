# %% [markdown]
# <a href="https://colab.research.google.com/github/Waed-Mishael/100codeDaysofCode/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Getting the data from the csv files
df_Sales_reciepts = pd.read_csv("/content/drive/MyDrive/archive_3/201904 sales reciepts.csv")
df_Dates = pd.read_csv("/content/drive/MyDrive/archive_3/Dates.csv")
df_custumer = pd.read_csv("/content/drive/MyDrive/archive_3/customer.csv")
df_generation = pd.read_csv("/content/drive/MyDrive/archive_3/generations.csv")
df_pastry_inventory = pd.read_csv("/content/drive/MyDrive/archive_3/pastry inventory.csv")
df_product = pd.read_csv("/content/drive/MyDrive/archive_3/product.csv")
df_sales_target = pd.read_csv("/content/drive/MyDrive/archive_3/sales targets.csv")
df_sales_outlet = pd.read_csv("/content/drive/MyDrive/archive_3/sales_outlet.csv")
df_staff = pd.read_csv("/content/drive/MyDrive/archive_3/staff.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# dollar = 3.68

# %%
# how did you overcome these ...
# recomendations and conclusions
# interesting things while programming

# %%
# Revenue: Total sales generated by the cafe, broken down by categories like coffee, food, merchandise, etc.
# Staff Productivity: Amount of revenue generated per staff member. # KPI how to improve
# Graphes
# problems for the development
#(The same variables name ALMOST but they are not the same)
#(a longer much better names)
# The dataset info

# %%
df_staff['start_date'] = pd.to_datetime(df_staff['start_date'])
df_staff.head(1)
# Staff Productivity: Amount of revenue generated per staff member. # KPI how to improve
# Out:
#    staff_id first_name last_name position start_date location  Unnamed: 6  \
# 0         1        Sue   Tindale      CFO 2001-08-03       HQ         NaN
#
#    Unnamed: 7
# 0         NaN

# %%
# how many staff do we have?
total_staff = df_staff.shape[0]
print("Total number of staff in the company:", total_staff)
total_outlets = df_sales_outlet.shape[0]
print("Total number of outlets in the company:", total_outlets)
# Out:
# Total number of staff in the company: 55
# Total number of outlets in the company: 9

# %%
df_custumer['customer_since'] = pd.to_datetime(df_custumer['customer_since'])
df_custumer['birthdate'] = pd.to_datetime(df_custumer['birthdate'])
df_custumer.head(2)

# Customer Service KPIs:
# Repeat Customer Rate: Percentage of customers who return for another visit. KPI how to improve
# Out:
#    customer_id  home_store customer_first-name        customer_email  \
# 0            1           3           Kelly Key  Venus@adipiscing.edu
# 1            2           3     Clark Schroeder        Nora@fames.gov
#
#   customer_since loyalty_card_number  birthdate gender  birth_year
# 0     2017-01-04        908-424-2890 1950-05-29      M        1950
# 1     2017-01-07        032-732-6308 1950-07-30      M        1950

# %%
df_generation.head(2)
# Out:
#    birth_year    generation
# 0        1946  Baby Boomers
# 1        1947  Baby Boomers

# %%
df_product['current_retail_price'] = df_product['current_retail_price'].str.replace("$", "").astype(float)
# df_product['current_retail_price'] = df_product['current_retail_price']*dollar
# run this just once
# Out:
# <ipython-input-24-df1a6f8f81c9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_product['current_retail_price'] = df_product['current_retail_price'].str.replace("$", "").astype(float)

# %%
# pd.to_numeric(df_product['current_retail_price'])
df_product.head(2)
# Out:
#    product_id    product_group product_category       product_type  \
# 0           1  Whole Bean/Teas     Coffee beans      Organic Beans
# 1           2  Whole Bean/Teas     Coffee beans  House blend Beans
#
#                     product  \
# 0       Brazilian - Organic
# 1  Our Old Time Diner Blend
#
#                                  product_description unit_of_measure  \
# 0     It's like Carnival in a cup. Clean and smooth.           12 oz
# 1  Out packed blend of beans that is reminiscent ...           12 oz
#
#    current_wholesale_price  current_retail_price tax_exempt_yn promo_yn  \
# 0                     14.4                  18.0             Y        N
# 1                     14.4                  18.0             Y        N
#
#   new_product_yn
# 0              N
# 1              N

# %%
df_pastry_inventory['transaction_date'] = pd.to_datetime(df_pastry_inventory['transaction_date'])
df_pastry_inventory.head(2)
# Out:
#    sales_outlet_id transaction_date  product_id  start_of_day  quantity_sold  \
# 0                3       2019-04-01          69            18              8
# 1                3       2019-04-01          70            18             12
#
#    waste % waste
# 0     10     56%
# 1      6     33%

# %%
df_Dates['transaction_date'] = pd.to_datetime(df_Dates['transaction_date'])
df_Dates.head(2)
# Out:
#   transaction_date   Date_ID  Week_ID Week_Desc  Month_ID Month_Name  \
# 0       2019-04-01  20190401       14   Week 14         4      April
# 1       2019-04-02  20190402       14   Week 14         4      April
#
#    Quarter_ID Quarter_Name  Year_ID
# 0           2           Q2     2019
# 1           2           Q2     2019

# %%
df_Sales_reciepts['transaction_date'] = pd.to_datetime(df_Sales_reciepts['transaction_date'])
df_Sales_reciepts['transaction_time'] = pd.to_datetime(df_Sales_reciepts['transaction_time'], format='%H:%M:%S')
# df_Sales_reciepts["unit_price"] = df_Sales_reciepts["unit_price"]*dollar
df_Sales_reciepts.head(2)
# Financial KPIs:
# Cost of Goods Sold (COGS): Cost of ingredients and other consumables used to make products sold.
# Gross Profit: Revenue minus COGS.
# Net Profit: Gross profit minus operating expenses like rent, labor, and utilities.
# Average Revenue Per Customer (ARPC): Total revenue divided by the number of customers served.
# Customer Lifetime Value (CLTV): The average amount of money a customer spends over their entire relationship with your cafe.
# Out:
#    transaction_id transaction_date    transaction_time  sales_outlet_id  \
# 0               7       2019-04-01 1900-01-01 12:04:43                3
# 1              11       2019-04-01 1900-01-01 15:54:39                3
#
#    staff_id  customer_id instore_yn  order  line_item_id  product_id  \
# 0        12          558          N      1             1          52
# 1        17          781          N      1             1          27
#
#    quantity  line_item_amount  unit_price promo_item_yn
# 0         1               2.5         2.5             N
# 1         2               7.0         3.5             N

# %%
df_sales_target["year_month"] = pd.to_datetime(df_sales_target["year_month"], format='%b-%y')
df_sales_target.head(20)
# Out:
#    sales_outlet_id year_month  beans_goal  beverage_goal  food_goal  \
# 0                3 2019-04-01         720          13500       3420
# 1                4 2019-04-01         720          13500       3420
# 2                5 2019-04-01        1000          18750       4750
# 3                6 2019-04-01         720          13500       3420
# 4                7 2019-04-01         720          13500       3420
# 5                8 2019-04-01         900          16875       4275
# 6                9 2019-04-01         720          13500       3420
# 7               10 2019-04-01         720          13500       3420
#
#    merchandise _goal  total_goal
# 0                360       18000
# 1                360       18000
# 2                500       25000
# 3                360       18000
# 4                360       18000
# 5                450       22500
# 6                360       18000
# 7                360       18000

# %%
df_sales_outlet.head(2)
# Out:
#    sales_outlet_id sales_outlet_type  store_square_feet       store_address  \
# 0                2         warehouse               3400  164-14 Jamaica Ave
# 1                3            retail               1300      32-20 Broadway
#
#          store_city store_state_province store_telephone  store_postal_code  \
# 0           Jamaica                   NY    972-871-0402              11432
# 1  Long Island City                   NY    777-718-3190              11106
#
#    store_longitude  store_latitude  manager Neighorhood
# 0       -73.795168       40.705226      NaN     Jamaica
# 1       -73.924008       40.761196      6.0     Astoria

# %%
df_Sales_reciepts
# filter
# Out:
#        transaction_id transaction_date    transaction_time  sales_outlet_id  \
# 0                   7       2019-04-01 1900-01-01 12:04:43                3
# 1                  11       2019-04-01 1900-01-01 15:54:39                3
# 2                  19       2019-04-01 1900-01-01 14:34:59                3
# 3                  32       2019-04-01 1900-01-01 16:06:04                3
# 4                  33       2019-04-01 1900-01-01 19:18:37                3
# ...               ...              ...                 ...              ...
# 49889             753       2019-04-29 1900-01-01 16:51:58                8
# 49890             756       2019-04-29 1900-01-01 16:51:14                8
# 49891             759       2019-04-29 1900-01-01 11:17:36                8
# 49892             763       2019-04-29 1900-01-01 15:45:52                8
# 49893             763       2019-04-29 1900-01-01 15:45:52                8
#
# ...

# %%
# Revenue: Total sales generated by the cafe, broken down by categories like coffee, food, merchandise, etc.
# Revenue = price * quantity    sales_outlet_id
filtered_df = df_Sales_reciepts[df_Sales_reciepts['transaction_date'] >= pd.Timestamp('2019-04-01')]

# Calculate revenue
filtered_df['revenue'] = filtered_df['quantity'] * filtered_df['unit_price']

# Group by 'sales_outlet_id' and calculate sum of revenue
outlet_revenue = filtered_df.groupby('sales_outlet_id')['revenue'].sum()

# # Convert outlet_revenue to DataFrame
outlet_revenue_df = pd.DataFrame(outlet_revenue).reset_index()
outlet_revenue_df.columns = ['sales_outlet_id', 'total_revenue']
outlet_revenue_df['target_revenue'] = [18000, 25000, 22500]
outlet_revenue_df['total_revenue'] = outlet_revenue_df['total_revenue'].round()
print(outlet_revenue_df['target_revenue'].sum())
# Out:
# 65500

# %%
selected_columns_product = ['product_id', 'product_group', 'product_category', 'current_wholesale_price', 'current_retail_price','tax_exempt_yn']
# Creating a new DataFrame with selected columns
df_selected_product = df_product[selected_columns_product]

selected_columns_sales = ['product_id','sales_outlet_id', 'quantity', 'unit_price','staff_id']
# Creating a new DataFrame with selected columns
df_selected_sales = df_Sales_reciepts[selected_columns_sales]

# Merge the two DataFrames on 'product_id' using outer join
df_merged = pd.merge(df_selected_product, df_selected_sales, on='product_id', how='outer')

df_merged['revenue'] = df_merged['quantity'] * df_merged['unit_price']

# Assuming you have your DataFrames df_selected_product and df_selected_sales already defined

# Merge the two DataFrames on 'product_id' using outer join
df_group_product_sales = pd.merge(df_selected_product, df_selected_sales, on='product_id', how='outer')

# Calculate revenue
df_group_product_sales['revenue'] = df_group_product_sales['quantity'] * df_group_product_sales['unit_price']

# Group by 'sales_outlet_id' and 'product_category' and calculate sum of revenue
grouped_revenue = df_group_product_sales.groupby(['sales_outlet_id','product_group'])['revenue'].sum().reset_index()


# df_sales_target
selected_sales_outlet_ids = [3, 5,8]

# Filter rows based on sales_outlet_id
filtered_sales_targets = df_sales_target.loc[df_sales_target['sales_outlet_id'].isin(selected_sales_outlet_ids)]

# %%
# Define the data
data = {
    'sales_outlet_id': [3, 5, 8],
    'beans_goal': [720, 1000, 900],
    'beverage_goal': [13500, 18750, 16875],
    'food_goal': [3420, 4750, 4275],
    'merchandise_goal': [360, 500, 450],
    'total_goal': [18000, 25000, 22500]
}

# Create DataFrame
df_target = pd.DataFrame(data)

import pandas as pd

# Define the data
data_real = {
    'sales_outlet_id': [3, 5, 8],
    'beans_real': [4919, 5484, 8383],
    'beverage_real': [61300, 58840, 60431],
    'food_real': [8837, 9484, 9186],
    'merchandise_real': [1848, 2140, 586],
    'total_real': [77482, 77201, 79528]
}

# here we got the revenue but not the profit so
# we have to get the Deductions but we don't have in this data
# but with research I got that on average cofee shops get 25% of thier revenue as profit

# Multiply numerical values by 25%
for key, values in data_real.items():
    if key != 'sales_outlet_id':
        data_real[key] = [int(value * 0.25) for value in values]
# Create DataFrame
df_real = pd.DataFrame(data_real)

# %%
sum_target = df_target['total_goal'].sum()
sum_real = df_real['total_real'].sum()

print(sum_target)
print(sum_real)
plt.bar(['Target', 'Real'], [sum_target, sum_real], color=['#33FFBD','#FF5733'])
plt.xlabel('Type')
plt.ylabel('Total Sum')
plt.title('Total Sum of Target vs Real')
plt.show()
# Out:
# 65500
# 58552

# %%
# Plotting
for outlet_id in df_target['sales_outlet_id']:
    fig, ax = plt.subplots()

    # Select data for the current sales_outlet_id
    target_values = df_target[df_target['sales_outlet_id'] == outlet_id].iloc[:, 1:].values.flatten()
    real_values = df_real[df_real['sales_outlet_id'] == outlet_id].iloc[:, 1:].values.flatten()
    columns = df_target.columns[1:]

    # Plot
    index = range(len(target_values))

    ax.plot(columns, target_values, label='Target', marker='o', color='#33FFBD')
    ax.plot(columns, real_values, label='Real', marker='o', color='#FF5733')

    ax.set_xlabel('Categories')
    ax.set_ylabel('Values')
    ax.set_title(f'Sales Outlet {outlet_id}: Target vs Real')
    ax.legend()

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

# Group by sales_outlet_id and sum the real total values
total_real_by_outlet = df_real.groupby('sales_outlet_id')['total_real'].sum()

# Plotting
plt.figure(figsize=(8, 8))
plt.pie(total_real_by_outlet, labels=total_real_by_outlet.index, autopct='%1.1f%%', startangle=140)
plt.title('Total Real Values by Outlet')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# # Assuming df_Sales_reciepts is your DataFrame
# # and you want to iterate over sales_outlet_id from 1 to 10
# # and calculate df_revenue_outlet
# df_revenue_outlet_list = []

# date < '01-04-2019'


# for i in range(1, 11):  # Loop from 1 to 10
#     df_revenue_outlet = np.where(df_Sales_reciepts['sales_outlet_id'] == i,
#                                   df_Sales_reciepts["unit_price"] * df_Sales_reciepts["quantity"],
#                                   0)
#     df_revenue_outlet_list.append(df_revenue_outlet)
# # Concatenate the results along axis 0 (rows)
# df_revenue_outlet = np.concatenate(df_revenue_outlet_list, axis=0)
# # Assuming you want to assign this to a DataFrame column
# df_Sales_reciepts['df_revenue_outlet'] = df_revenue_outlet
# # Now df_Sales_reciepts contains the column df_revenue_outlet with values based on the conditions

# %%
# Staff Productivity: Amount of revenue generated per staff member. # KPI how to improve
# Create a new DataFrame with selected columns

df_group_staff_sales = pd.merge(df_staff, df_selected_sales, on='staff_id', how='outer')

# Calculate revenue
df_group_staff_sales['revenue'] = df_group_staff_sales['quantity'] * df_group_staff_sales['unit_price']

grouped_revenue_staff = df_group_staff_sales.groupby(['staff_id', 'first_name', 'last_name', 'position','location'])['revenue'].sum().reset_index()

# Store Manager,Coffee Wrangler


grouped_revenue_by_position = grouped_revenue_staff.groupby('position')['revenue'].sum().reset_index()


# Filter the DataFrame to include only rows where the position is "Store Manager"
df_store_managers = grouped_revenue_staff[grouped_revenue_staff['position'] == 'Store Manager']

# Calculate the average revenue for Store Managers
average_revenue_store_manager = df_store_managers['revenue'].mean()

# Filter the DataFrame to include only rows where the position is "Coffee Wrangler"
df_coffee_wranglers = grouped_revenue_staff[grouped_revenue_staff['position'] == 'Coffee Wrangler']

# Calculate the average revenue for Coffee Wranglers
average_revenue_coffee_wrangler = df_coffee_wranglers['revenue'].mean()

print("Average Revenue for Coffee Wranglers:", average_revenue_coffee_wrangler)
print("Average Revenue for Store Managers:", average_revenue_store_manager)
grouped_revenue_by_position

# We have some outlits where the store maneger who we pay him/her more because they should manage the
#Business but in the end their presuce time goes on seling. This is a question!
# Out:
# Average Revenue for Coffee Wranglers: 4725.4217499999995
# Average Revenue for Store Managers: 4519.467999999999
#           position    revenue
# 0              CEO       0.00
# 1              CFO       0.00
# 2  Coffee Wrangler  189016.87
# 3          Roaster       0.00
# 4    Store Manager   45194.68

# %%
import matplotlib.pyplot as plt

# Data
positions = ['Coffee Wrangler', 'Store Manager']
average_revenues = [4725.42, 4519.47]  # Average revenue values

# Create bar plot
plt.bar(positions, average_revenues, color=['skyblue', 'lightgreen'])  # You can adjust colors as needed
plt.xlabel('Position')
plt.ylabel('Average Revenue')
plt.title('Average Revenue by Position')
plt.ylim(0, max(average_revenues) * 1.1)  # Set y-axis limit to ensure all data is visible
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
positions = grouped_revenue_by_position['position']
revenues = grouped_revenue_by_position['revenue']

# Create bar plot
plt.bar(positions, revenues, color=['#33FF57'])  # You can adjust colors as needed
plt.xlabel('Position')
plt.ylabel('Total Revenue')
plt.title('Total Revenue by Position')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()

# Show plot
plt.show()

# %%
# Filter the DataFrame to include only staff members with the position "Coffee Wrangler"
df_coffee_wranglers = df_group_staff_sales[df_group_staff_sales['position'] == 'Coffee Wrangler']

# Group by staff ID, first name, and last name, and calculate sum of revenue for each Coffee Wrangler
grouped_revenue_coffee_wranglers = df_coffee_wranglers.groupby(['staff_id', 'first_name', 'last_name','start_date','location'])['revenue'].sum().reset_index()

print("Grouped Revenue by Coffee Wrangler:")
grouped_revenue_coffee_wranglers
# Out:
# Grouped Revenue by Coffee Wrangler:
#     staff_id first_name last_name start_date location   revenue
# 0          7     Kelsey   Cameron 2003-10-18        3   3170.71
# 1          8   Hamilton       Emi 2005-02-09        3   1328.55
# 2          9   Caldwell      Veda 2013-09-09        3   1694.10
# 3         10        Ima  Winifred 2016-12-10        3    949.35
# 4         12   Britanni    Jorden 2006-03-25        4  27609.34
# 5         13       Berk     Derek 2009-12-11        4    392.80
# 6         14      Damon     Sasha 2010-06-05        4  12851.72
# 7         15   Remedios      Mari 2014-05-09        4   9161.73
# 8         17      Quail   Octavia 2014-12-05        5  14062.99
# 9         18    Ezekiel    Rashad 2005-11-13        5   2221.40
# 10        19      Peter    Paloma 2014-03-12        5   2450.58
# 11        20      Ronan     Magee 2002-02-13        5  14291.76
# 12        22      Marny    Dennis 2014-03-03        6      0.00
# ...

# %%
# Plot the grouped revenue data for Coffee Wranglers
plt.figure(figsize=(10, 6))
plt.bar(grouped_revenue_coffee_wranglers['first_name'] + ' ' + grouped_revenue_coffee_wranglers['last_name'],
        grouped_revenue_coffee_wranglers['revenue'])
plt.xlabel('Coffee Wrangler')
plt.ylabel('Revenue')
plt.title('Revenue Generated by Coffee Wranglers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Filter the DataFrame to include only Coffee Wranglers with zero revenue
coffee_wranglers_zero_revenue = grouped_revenue_coffee_wranglers[grouped_revenue_coffee_wranglers['revenue'] == 0]

# Count the number of Coffee Wranglers with zero revenue
num_coffee_wranglers_zero_revenue = len(coffee_wranglers_zero_revenue)
all_coffee_wranglers = len(grouped_revenue_coffee_wranglers)
print("Number of Coffee Wranglers with zero revenue:", num_coffee_wranglers_zero_revenue)
print("Number of Coffee Wranglers with positive revenue:", all_coffee_wranglers)


# They have 19 Coffee Wranglers out of 40 that they sell nothing in april.
# it could be because they did not work that month or the store did not open
# I dont have the data of what outlit they work in but maybe that is why the
# store manegare was selling instead of doing his/her job
# in this case we should conseder an uegent meeting to see what was the problem and know that this
# situation will never be again!
# this is a הפסד אבסןלןתי!
# But if the store was opened and they were working it is another question why?
# it could be that the maneger let the workers sell in his/her name!
# Out:
# Number of Coffee Wranglers with zero revenue: 19
# Number of Coffee Wranglers with positive revenue: 40

# %%
# Filter the DataFrame to include only staff members with the position "Store Manager"
df_store_managers = df_group_staff_sales[df_group_staff_sales['position'] == 'Store Manager']

# Group by staff ID, first name, last name, and start date, and calculate sum of revenue for each Store Manager
grouped_revenue_store_managers = df_store_managers.groupby(['staff_id', 'first_name', 'last_name', 'start_date','location'])['revenue'].sum().reset_index()
grouped_revenue_store_managers
# Out:
#    staff_id first_name last_name start_date location   revenue
# 0         6       Xena     Rahim 2016-07-24        3   7901.99
# 1        11       Ruth    Leslie 2009-06-17        4      0.00
# 2        16       Reed       Eve 2006-03-30        5  14687.49
# 3        21    Melodie  Mercedes 2018-09-29        6      0.00
# 4        26     Joelle  Christen 2013-11-11        7  17144.96
# 5        31       Dawn   Anthony 2009-07-02        8      0.00
# 6        36    Anthony   Kaitlin 2004-04-19        9      0.00
# 7        41     Adrian     Macon 2001-10-13       10   5460.24
# 8        46    Desiree     Anika 2008-06-15       FL      0.00
# 9        51   Lawrence   Roberts 2001-08-03       FL      0.00

# %%
# Plot the grouped revenue data for Store Managers
plt.figure(figsize=(10, 6))
plt.bar(grouped_revenue_store_managers['first_name'] + ' ' + grouped_revenue_store_managers['last_name'],
        grouped_revenue_store_managers['revenue'])
plt.xlabel('Store Manager')
plt.ylabel('Revenue')
plt.title('Revenue Generated by Store Managers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define colors for each position
position_colors = {
    'Coffee Wrangler': 'skyblue',
    'Store Manager': 'red'
}

# Group the data by location
grouped_by_location = df_group_staff_sales.groupby('location')

# Plot revenue for each location
for location, group in grouped_by_location:
    plt.figure(figsize=(8, 6))
    for _, worker in group.iterrows():
        plt.bar(worker['first_name'] + ' ' + worker['last_name'], worker['revenue'], color=position_colors.get(worker['position'], 'gray'))

    # Create a legend
    legend_colors = [plt.Rectangle((0,0),1,1, color=color) for color in position_colors.values()]
    plt.legend(legend_colors, position_colors.keys(), loc='upper left')

    plt.xlabel('Worker')
    plt.ylabel('Revenue')
    plt.title(f'Revenue Generated by all Workers at Location {location}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# %%
# Repeat Customer Rate: Percentage of customers who return for another visit. KPI how to improve
# Average Revenue Per Customer (ARPC): Total revenue divided by the number of customers served.
# if the  Repeat Customer Rate is low try to give copons for buying every day etc...
# it the Average Revenue Per Customer is low try that they will buy more in each visit

# %%
merged_custumer_reciept_df = pd.merge(df_custumer, df_Sales_reciepts, on='customer_id', how='inner')
# Calculate the total number of unique customers
total_customers = merged_custumer_reciept_df['customer_id'].nunique()
print(total_customers)

# %%
# Filter the DataFrame to include only customers who have made more than one visit
repeat_customers_df = merged_custumer_reciept_df['customer_id'].value_counts().loc[lambda x: x > 1]

# Calculate the number of visits per repeat customer
repeat_visits = repeat_customers_df - 1  # Subtract 1 because the first visit is not counted as a return

# Calculate the average number of visits
average_return_visits = repeat_visits.mean()

print("Average number of customers returning two times:", average_return_visits)

# %%
# Initialize lists to store visit counts and corresponding percentages
visit_counts = []
percentages = []

# Loop through different visit counts from 1 to 100
for visit_count in range(1, 31):
    # Filter the DataFrame to include only customers who have made more than or equal to visit_count visits
    customers_returning_count = (merged_custumer_reciept_df['customer_id'].value_counts() == visit_count).sum()

    # Calculate the percentage of customers returning equal to or more than visit_count times
    percentage_returning_count = (customers_returning_count / total_customers) * 100

    # Append visit count and percentage to lists
    visit_counts.append(visit_count)
    percentages.append(percentage_returning_count)

# Plot the line graph
plt.plot(visit_counts, percentages)
plt.xlabel('Visit Count')
plt.ylabel('Percentage of Customers')
plt.title('Percentage of Customers Returning in one month')
plt.grid(True)
plt.show()

# %%
# Assuming 'merged_df' contains the merged DataFrame with customer visits data

# Sort the DataFrame by customer_id and transaction_date
merged_df_sorted = merged_custumer_reciept_df.sort_values(by=['customer_id', 'transaction_date'])

# Initialize an empty list to store time differences
time_diffs = []

# Group the DataFrame by customer_id
grouped = merged_df_sorted.groupby('customer_id')

# Iterate over each group (customer)
for customer_id, group in grouped:
    # Filter the group to include only return visits (visits after the first visit)
    return_visits = group.iloc[1:]

    # Calculate the time difference between consecutive return visits
    time_diff = return_visits['transaction_date'].diff().dt.total_seconds().mean()

    # Append the time difference to the list
    time_diffs.append(time_diff)

# Calculate the average time difference between return visits across all customers
average_time_diff = pd.Series(time_diffs).mean()

# Convert the average time difference from seconds to days for better readability
average_time_diff_days = average_time_diff / (60 * 60 * 24)
print("Average time between return visits (in days):", average_time_diff_days)

# %%
df_merged_with_generation = pd.merge(merged_custumer_reciept_df, df_generation, on='birth_year', how='left')
df_merged_with_generation

# %%
import pandas as pd

# Convert 'transaction_date' to datetime
df_merged_with_generation['transaction_date'] = pd.to_datetime(df_merged_with_generation['transaction_date'])

# Sort DataFrame by 'customer_id' and 'transaction_date' to ensure proper calculation
df_merged_with_generation = df_merged_with_generation.sort_values(by=['customer_id', 'transaction_date'])

# Calculate time difference between consecutive visits for each customer
df_merged_with_generation['time_diff'] = df_merged_with_generation.groupby('customer_id')['transaction_date'].diff().dt.days

# Drop NaN values (first visit of each customer)
df_merged_with_generation.dropna(subset=['time_diff'], inplace=True)

# Assuming 'generation' is a column in the DataFrame representing the generation of each customer

# Group by 'generation' and calculate the average time difference
average_time_between_visits_by_generation = df_merged_with_generation.groupby('generation')['time_diff'].mean()

print(average_time_between_visits_by_generation)

# %%
# Plotting
plt.figure(figsize=(10, 6))
average_time_between_visits_by_generation.plot(kind='bar', color='skyblue')
plt.xlabel('Generation')
plt.ylabel('Average Time Difference between Visits (Days)')
plt.title('Average Time Difference between Visits by Generation')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate total revenue
total_revenue = df_merged_with_generation['line_item_amount'].sum()

# Calculate the number of unique customers served
num_unique_customers = df_merged_with_generation['customer_id'].nunique()

# Calculate the average revenue per customer
average_revenue_per_customer = total_revenue / num_unique_customers

print("Average Revenue Per Customer:", average_revenue_per_customer)

# %%
# Calculate total revenue
total_revenue = df_merged_with_generation['line_item_amount'].sum()

# Calculate the number of unique customers served
num_unique_customers = df_merged_with_generation['customer_id'].nunique()

# Calculate the average revenue per customer
average_revenue_per_customer = total_revenue / num_unique_customers

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(['Average Revenue per Customer'], [average_revenue_per_customer], color='skyblue')
plt.xlabel('Metric')
plt.ylabel('Value')
plt.title('Average Revenue Per Customer')
plt.ylim(0, None)  # Set y-axis limit to start from 0
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
